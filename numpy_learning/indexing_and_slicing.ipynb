# %%
import numpy as np

# %%
arr = np.array([[1,2,3],[3,2,1],[4,5,6],[7,8,9]])

# %%
arr
# Out:
# array([[1, 2, 3],
#        [3, 2, 1],
#        [4, 5, 6],
#        [7, 8, 9]])

# %%
flat_array = arr.flatten()

# %%
flat_array
# Out:
# array([1, 2, 3, 3, 2, 1, 4, 5, 6, 7, 8, 9])

# %%
flat_array[0]
# Out:
# np.int64(1)

# %%
flat_array[3:6]
# Out:
# array([3, 2, 1])

# %%
flat_array[:7]
# Out:
# array([1, 2, 3, 3, 2, 1, 4])

# %%
flat_array[6:]
# Out:
# array([4, 5, 6, 7, 8, 9])

# %% [markdown]
# Changing an element in the instance created by the array slicing also change on its original one too
# as slicing returns an view not an copy this is the feature of numpy

# %%
new_array = flat_array[3:8]

# %%
new_array
# Out:
# array([3, 2, 1, 4, 5])

# %%
new_array[1]= 12345

# %%
new_array
# Out:
# array([    3, 12345,     1,     4,     5])

# %%
flat_array
# Out:
# array([    1,     2,     3,     3, 12345,     1,     4,     5,     6,
#            7,     8,     9])

# %% [markdown]
# ### to make a copy use .copy()

# %%
new2 = flat_array[2:8].copy()

# %%
new2
# Out:
# array([    3,     3, 12345,     1,     4,     5])

# %%
new2[2] = 2

# %%
new2
# Out:
# array([3, 3, 2, 1, 4, 5])

# %%
flat_array
# Out:
# array([    1,     2,     3,     3, 12345,     1,     4,     5,     6,
#            7,     8,     9])

# %% [markdown]
# ----------------------------------------

# %%
flat_array[flat_array>4] #satisfy condition
# Out:
# array([12345,     5,     6,     7,     8,     9])
