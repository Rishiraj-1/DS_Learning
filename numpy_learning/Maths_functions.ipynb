# %%
import numpy as np 
arr = np.array([1,2,3,4,5])
arr1 = np.array([1,2,3,4])
arr2 = np.array([5,6,7,8])

# %% [markdown]
# np.mean() – Compute the mean (average) of an array.

# %%
np.mean(arr)
# Out:
# np.float64(3.0)

# %% [markdown]
# np.std() – Compute the standard deviation of an array.

# %%
np.std(arr)
# Out:
# np.float64(1.4142135623730951)

# %% [markdown]
# np.var(arr) - Compute the variance of an array

# %%
np.var(arr)
# Out:
# np.float64(2.0)

# %% [markdown]
# np.min() - Compute the minimum value of an array

# %%
np.min(arr)
# Out:
# np.int64(1)

# %% [markdown]
# np.max() - Compute the maximum value of an array

# %%
np.max(arr)
# Out:
# np.int64(5)

# %% [markdown]
# np.sum() -Compute the sum of all elements in an array

# %%
np.sum(arr)
# Out:
# np.int64(15)

# %% [markdown]
# np.prod() - compute the product of all elements in an array/

# %%
np.prod(arr)
# Out:
# np.int64(120)

# %% [markdown]
# np.median() - Compute the median of an array

# %%
np.median(arr)
# Out:
# np.float64(3.0)

# %% [markdown]
# np.percentile() - Compute the percentile of an array

# %%
np.percentile(arr,50)  #for the 50th percentile
# Out:
# np.float64(3.0)

# %% [markdown]
# np.argmin() - return the index of minimum value in an array

# %%
np.argmin(arr)
# Out:
# np.int64(0)

# %% [markdown]
# np.argmax() - return the index of maximum value in an array

# %%
np.argmax(arr)
# Out:
# np.int64(4)

# %% [markdown]
# np.corrcoef() - compute the correlation coefficient matrix of two arrays

# %%
np.corrcoef(arr1,arr2)
# Out:
# array([[1., 1.],
#        [1., 1.]])

# %% [markdown]
# np.unique() - find the unique elements of an array

# %%
np.unique(arr)
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
# np.diff() - Compute the nth differnces of an array

# %%
np.diff(arr)
# Out:
# array([1, 1, 1, 1])

# %% [markdown]
# np.cumsum() - Compute the cumulative sum of an array

# %%
np.cumsum(arr)
# Out:
# array([ 1,  3,  6, 10, 15])

# %% [markdown]
# np.linspace() - Create an array with evenly spaced number over a specific interval

# %%
np.linspace(0,10,5)
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %% [markdown]
# np.log() -compute the natural logarithm of an array

# %%
np.log(arr)
# Out:
# array([0.        , 0.69314718, 1.09861229, 1.38629436, 1.60943791])

# %% [markdown]
# np.exp() - Compute the exponential of an array

# %%
np.exp(arr)
# Out:
# array([  2.71828183,   7.3890561 ,  20.08553692,  54.59815003,
#        148.4131591 ])
