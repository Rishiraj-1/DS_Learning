# %% [markdown]
# int 32, int64
#
# float 32
#
# bool
#
# complex64
#
# object

# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.astype("float64")
# Out:
# array([1., 2., 3., 4., 5.])

# %%
arr2 = np.array([4,5,6,7,8,9],dtype="float32")

# %%
arr2
# Out:
# array([4., 5., 6., 7., 8., 9.], dtype=float32)

# %%
arr_int64 = np.array([1,2,3],dtype=np.int64)

# %%
arr_int32 = np.array([1,2,3],dtype=np.int32)

# %%
arr_int16 = np.array([1,2,3],dtype=np.int16)

# %%
arr_int64.nbytes
# Out:
# 24

# %%
arr_int32.nbytes
# Out:
# 12

# %%
arr_int16.nbytes
# Out:
# 6

# %%
arr2.nbytes
# Out:
# 24

# %%
complex_num = np.array([1 + 2j , 4 + 4j , 5 + 7j] , dtype='complex128')

# %%
complex_num
# Out:
# array([1.+2.j, 4.+4.j, 5.+7.j])
