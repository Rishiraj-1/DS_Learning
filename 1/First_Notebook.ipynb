# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# ## Python Tutorial

# %% [markdown]
# this is an python language tutorial

# %% [markdown]
# - its amazing
# - its wonderful

# %% [markdown]
# # Rishiraj

# %%
a=8

# %%
b=10

# %%
a+b
# Out:
# 18
