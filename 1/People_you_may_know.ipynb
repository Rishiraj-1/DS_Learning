# %%
import json 
def load_data(filename):
    with open("data.json","r") as f:
        return json.data(f)

def find_people_you_may_know(user_id,data):
    user_friends = {} # creationg a dictionary
    for user in data['friends']:
        user_friends[user['id']] = set

#load the data
data = load_data("data.json")
user_id = 1  # user whose recommendation we want 
reccomendation = find_people_you_may_know(user_id,data)
print(reccomendation)
# Out:
#   Cell In[3], line 11
#     data = load_data("data.json")
#                                  ^
# IndentationError: expected an indented block after 'for' statement on line 8
